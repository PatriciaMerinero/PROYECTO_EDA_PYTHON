# %% [markdown]
# ## Importación librerias

# %%
# Manejo y análisis de datos
import pandas as pd        # Tablas de datos, lectura de CSV/Excel, limpieza y transformación
import numpy as np         # Cálculos numéricos, estadística básica, arrays

# Geolocalización y países
import reverse_geocoder as rg  # Obtener país/ciudad a partir de coordenadas (lat, long)
import pycountry               # Normalizar nombres de países, idiomas y divisas

# Visualización
import seaborn as sns          # Gráficos estadísticos (histogramas, boxplots, heatmaps)
import matplotlib.pyplot as plt # Gráficos básicos y personalización detallada

# Rutas y entorno
from pathlib import Path        # Manejo de rutas de archivos/carpetas de forma portable

# Utilidades en Jupyter
from IPython.display import display  # Mostrar DataFrames y objetos con formato más claro que print()

# %% [markdown]
# ## Comprobación entorno
# Terminal, Kernel y notebook mismo entorno

# %%
import sys, os
print(sys.executable)          
print(os.environ.get("VIRTUAL_ENV"))
# Out:
# c:\Users\Propietario\Desktop\PROYECTO_PYTHON_FOR_DATA\PROYECTO_EDA_PYTHON\.venv\Scripts\python.exe
# C:\Users\Propietario\Desktop\proyecto_python_for_data\PROYECTO_EDA_PYTHON\.venv

# %% [markdown]
# # ****1er. Dataset . Carga de datos. Información****

# %%
df_customer = pd.read_excel("../Data/Raw/customer-details.xlsx")

# %% [markdown]
# Uno todas las hojas del Excell

# %%
df_customer = pd.concat(
    pd.read_excel("../Data/Raw/customer-details.xlsx", sheet_name=None).values(),
    ignore_index=True
)

# %%
df_customer. sample(10)
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 22841        2726  132464        1         2  2013-02-24                  6
# 27545        7430   37169        2         1  2013-09-05                 26
# 5380         5380   70242        2         0  2012-02-14                 24
# 12522       12522   56333        2         2  2012-02-09                  9
# 19037       19037   63700        1         0  2012-09-05                  3
# 11460       11460  115967        0         2  2012-03-24                 26
# 7655         7655  110125        1         1  2012-05-25                 31
# 1664         1664   19382        2         2  2012-09-26                  4
# 35076        5996  155954        0         0  2014-10-25                  3
# 42618       13538    8619        0         0  2014-04-06                 12
#
#                                          ID
# 22841  821ff5c5-57fb-4477-a712-7c13dafb4625
# 27545  16483fd9-e10e-4e78-8655-6523c5daa345
# 5380   995a8e68-9f88-4333-85d5-af89d0cb1f73
# 12522  c588ddac-2edf-4237-9025-a24a9cc2a860
# 19037  b923f211-4847-4789-b106-acd7303f8c27
# 11460  9ef69130-bc21-4c22-8e15-173b9f9e8cbd
# 7655   6b53b677-4e21-472a-be22-9a24bc7560bc
# 1664   c829a9f4-24d8-449e-b113-4341c426d436
# 35076  d79c83b8-2ccf-4e8e-a5ae-e31d0111e361
# 42618  8b78d60d-9fac-4f93-b174-203501194b00

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         43170 non-null  int64
#  1   Income             43170 non-null  int64
#  2   Kidhome            43170 non-null  int64
#  3   Teenhome           43170 non-null  int64
#  4   Dt_Customer        43170 non-null  datetime64[ns]
#  5   NumWebVisitsMonth  43170 non-null  int64
#  6   ID                 43170 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# # Columnas e información
#
# 0. Unnamed: 0 (int64)
#
# No es una variable útil: se puede eliminar.
#
# 1. Income (int64)
#
# Ingresos de la persona/cliente: análisis socioeconómico
#
# 2. Kidhome (int64)
#
# Número de hijos pequeños en el hogar: variable numérica
#
# 3. Teenhome (int64)
#
# Número de adolescentes en el hogar: variable numérica
#
# 4. Dt_Customer (datetime64)
#
# Fecha en la que el cliente se unió / fue registrado: antiguedad.
#
# 5. NumWebVisitsMonth (int64)
#
# Número de visitas web al mes: comportamiento online.
#
# 6. ID (object)
#
# Identificador único del cliente: clave primaria.

# %% [markdown]
# # ****LIMPIEZA Y TRANSFORMACIÓN****

# %% [markdown]
# # 1. Eliminar Unnamed
#
# 1. Ver todas las columnas
# 2. Quito cualquier columna que empiece por Unnamed
# 3. Confirmo resultado

# %%
print(df_customer.columns)

df_customer = df_customer.loc[:, ~df_customer.columns.str.contains('^Unnamed')]

print(df_customer.columns)
# Out:
# Index(['Unnamed: 0', 'Income', 'Kidhome', 'Teenhome', 'Dt_Customer',
#        'NumWebVisitsMonth', 'ID'],
#       dtype='object')
# Index(['Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'NumWebVisitsMonth',
#        'ID'],
#       dtype='object')

# %% [markdown]
# # 2. Revisar duplicados de id
#
# 1. Nº de IDs totales
# 2. Nº de IDs únicos
# 3. Nº de duplicados

# %%
total_ids = df_customer['ID'].shape[0]

unique_ids = df_customer['ID'].nunique()

duplicated_ids = total_ids - unique_ids

print("Total de registros:", total_ids)
print("IDs únicos:", unique_ids)
print("Duplicados:", duplicated_ids)
# Out:
# Total de registros: 43170
# IDs únicos: 43170
# Duplicados: 0

# %% [markdown]
# # 3. Distribución de Income
#
# 1. Aseguro tipo numérico y revisa nulos
# 2. Chequeos rápidos de calidad
# 3. Detección de outliers (regla IQR): No se detectan outliers en la variable Income según la regla IQR y percentiles (p01–p99). Se mantiene la variable sin modificaciones.
# 4. Umbrales percentil
# 5. Boxplot de Income

# %%
#1. Aseguro tipo numérico y reviso nulos
df_customer['Income'] = pd.to_numeric(df_customer['Income'], errors='coerce')

print(df_customer['Income'].dtype)
print('Nulos en Income:', df_customer['Income'].isna().sum())
df_customer['Income'].describe()
# Out:
# int64
# Nulos en Income: 0
# count     43170.000000
# mean      93227.389622
# std       50498.181989
# min        5841.000000
# 25%       49608.000000
# 50%       93009.500000
# 75%      136740.500000
# max      180802.000000
# Name: Income, dtype: float64

# %%
# 2. Chequeos rápidos de calidad
print('<=0:', (df_customer['Income'] <= 0).sum())

df_customer['Income'].quantile([0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# <=0: 0
# 0.25     49608.00
# 0.50     93009.50
# 0.75    136740.50
# 0.90    163197.40
# 0.95    172366.75
# 0.99    179057.00
# Name: Income, dtype: float64

# %%
# 3. Detección de outliers (regla IQR)
q1 = df_customer['Income'].quantile(0.25)
q3 = df_customer['Income'].quantile(0.75)
iqr = q3 - q1
low  = q1 - 1.5*iqr
high = q3 + 1.5*iqr

df_customer['income_outlier_iqr'] = ~df_customer['Income'].between(low, high)
df_customer['income_outlier_iqr'].value_counts()
# Out:
# income_outlier_iqr
# False    43170
# Name: count, dtype: int64

# %%
# 4. Umbrales percentil
p01 = df_customer['Income'].quantile(0.01)
p99 = df_customer['Income'].quantile(0.99)

# %% [markdown]
# Realizo un boxplot income como verificación visual de la distribución y confirmación de que no existen outliers

# %%
#5. Boxplot de income

plt.figure(figsize=(6,4))
sns.boxplot(x=df_customer['Income'])
plt.title('Boxplot de Income')
plt.show()

# %% [markdown]
# # 4. Distribución de Kidhome y Teenhome: hogares sin hijos, con hijos.
# 1. Importo Numpy
# 2. Conviero las columnas en nº enteros, errores en NaN.
# 3. Distribución y nulos
# 4. Total de hijos. Creo variable deribada.

# %%
# 2. Convierto en nº enteros, errores.

for c in ['Kidhome','Teenhome']:
    df_customer[c] = pd.to_numeric(df_customer[c], errors='coerce').astype('Int64')

# %%
# 3. Distribución básica y nulos

for c in ['Kidhome','Teenhome']:
    print(f"{c}  - nulos:", df_customer[c].isna().sum())
    print(df_customer[c].value_counts(dropna=False).sort_index(), "\n")
# Out:
# Kidhome  - nulos: 0
# Kidhome
# 0    14270
# 1    14425
# 2    14475
# Name: count, dtype: Int64
#
# Teenhome  - nulos: 0
# Teenhome
# 0    14402
# 1    14425
# 2    14343
# Name: count, dtype: Int64

# %%
# 4. Total de hijos
df_customer['Children_total'] = (df_customer['Kidhome'] . fillna(0) +
                                                    df_customer['Teenhome'] . fillna(0)). astype ('int64')

# %% [markdown]
# Confirmo la creación de la columna =total children

# %%
df_customer. sample(20)
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 14473  136085        0         2  2012-09-06                 28
# 40084  124051        1         2  2014-11-16                 20
# 35274  177174        1         1  2014-03-31                 18
# 34072  147378        1         1  2014-10-15                  8
# 18500  125557        1         1  2012-07-15                 27
# 14465  115300        2         1  2012-08-30                 11
# 18189   34310        0         2  2012-07-03                 30
# 16850   66486        1         0  2012-08-30                 23
# 36740  154693        0         1  2014-02-17                 16
# 2059   117592        0         1  2012-06-26                  5
# 36015  164090        0         0  2014-08-29                 14
# 28054   62510        1         0  2013-09-30                 18
# 24723   29462        2         1  2013-08-04                 16
# 30844   55525        1         1  2014-12-03                 27
# 2135   116107        2         0  2012-09-29                  6
# 29699   41175        2         0  2014-08-19                  4
# 3299    47160        2         0  2012-09-08                  7
# 15458   69645        2         0  2012-06-18                 17
# 39872  154047        2         1  2014-11-02                  5
# 11945   32358        2         0  2012-09-14                 21
#
#                                          ID  income_outlier_iqr  \
# 14473  81df328e-0944-4a86-bc14-5b9c26e2e785               False
# 40084  01d6fc07-9b3c-48b4-8e0a-7ec38c8c52c6               False
# 35274  0a3272de-043a-43dc-8bbd-2e2d68d071e7               False
# 34072  8181fca5-52d9-4007-a48b-58364ea27de9               False
# 18500  c73137e6-103c-4867-b816-ce5e7e38ae1f               False
# 14465  cc938a6e-24de-4879-8dba-3f718da0f36e               False
# 18189  6303beb2-7bf9-4d32-aeb4-6667907ebdf3               False
# 16850  06790b09-18d9-4e51-ae25-3711cf5998a7               False
# 36740  ddfb1b61-8348-4228-a3d2-eb39886473bd               False
# 2059   985ad3d2-e5df-4fd8-bb43-322bd1a22639               False
# 36015  47bfbbe1-8ce8-4a3e-9004-6f3c4c83afe3               False
# 28054  528ecf93-ccce-4488-a467-c1a9fda2bb3b               False
# 24723  7c58cdee-c581-4b23-acec-6a9ecc375d4e               False
# 30844  7f779717-5af7-44d7-a669-5c9e5d973dc2               False
# 2135   2a5be51f-d61a-407d-96e0-d2c4a24c6c4d               False
# 29699  8dd4f2d8-f757-4c42-ae66-2edae18dc997               False
# 3299   aa625e30-ceec-4f3a-9429-d96eee5bb9fe               False
# 15458  51a61a6b-7046-4901-97ba-b20ae14eacf6               False
# 39872  ac951ffc-d5d3-4f8b-8de0-fd5b69572ace               False
# 11945  6687e1c7-911e-4261-b278-9618cb4243a1               False
#
#        Children_total
# 14473               2
# 40084               3
# 35274               2
# 34072               2
# 18500               2
# 14465               3
# 18189               2
# 16850               1
# 36740               1
# 2059                1
# 36015               0
# 28054               1
# 24723               3
# 30844               2
# 2135                2
# 29699               2
# 3299                2
# 15458               2
# 39872               3
# 11945               2

# %% [markdown]
# Realizo un boxplot de la variable Children_total como verificación visual de la distribución y confirmación de que no existen outliers.

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df_customer['Children_total'])
plt.title("Boxplot de número total de hijos")
plt.show()

# %% [markdown]
# # 5. Antiguedad del cliente. Creo columna.
# 1. Aseguro que la columna es tipo fecha
# 2. Fecha de referencia hoy
# 3. Creo columna con años antiguedad
# 4. Compruebo resultado

# %%
df_customer["Dt_Customer"] = pd.to_datetime(df_customer["Dt_Customer"], errors="coerce")   
ref_date = pd.Timestamp.today().normalize()
df_customer["Customer_Tenure_Years"] = ((ref_date - df_customer["Dt_Customer"]).dt.days // 365).astype("Int64")
df_customer[["Dt_Customer", "Customer_Tenure_Years"]].head()
# Out:
#   Dt_Customer  Customer_Tenure_Years
# 0  2012-04-04                     13
# 1  2012-12-30                     12
# 2  2012-02-02                     13
# 3  2012-12-21                     12
# 4  2012-06-20                     13

# %%
df_customer. sample(20)
# Out:
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 4569    92088        1         1  2012-01-23                 13
# 24552   96513        0         1  2013-12-20                 23
# 3086   173162        1         0  2012-07-16                 26
# 22617   23566        1         1  2013-12-11                  9
# 27197  114964        2         2  2013-12-13                 21
# 24190   29437        0         1  2013-06-18                 31
# 12156  165440        1         1  2012-09-02                 26
# 8238    85875        2         1  2012-09-21                 10
# 36640   25606        0         2  2014-01-10                 28
# 13839  118174        2         0  2012-11-02                 31
# 6165   163953        1         2  2012-08-25                 29
# 14200    5996        0         1  2012-01-24                  3
# 27451    6970        2         1  2013-10-14                  4
# 18568   13384        1         2  2012-12-21                  9
# 42863  153448        2         0  2014-11-12                 32
# 29459   74502        0         0  2014-01-13                 17
# 19025   43427        0         2  2012-02-26                  1
# 14485   13499        0         2  2012-06-03                 30
# 32790  112381        1         1  2014-02-27                  7
# 18918   62245        1         2  2012-08-15                 16
#
#                                          ID  income_outlier_iqr  \
# 4569   00e8828b-a132-43ea-872d-4397508427c3               False
# 24552  efb57beb-da61-49a0-885a-c37770bd3a64               False
# 3086   edb674fa-037c-48e5-8726-531ea92bfff2               False
# 22617  e5924a0f-3b2d-43f3-bbb7-3b5af4c18799               False
# 27197  3b354f72-d88f-4a19-813f-17e270f2d59b               False
# 24190  100bc0ac-b84a-463a-a10e-6fcc5a038dee               False
# 12156  ef660cdb-c90a-41d2-86cc-61f6163e48f5               False
# 8238   a26ab306-ebd5-468d-a839-12d47c14cb83               False
# 36640  007bf77f-c4a3-4b04-b0d2-18749183c731               False
# 13839  d699bb52-20e5-4d21-a42f-8e4284bd2a8e               False
# 6165   f83f06cb-0a99-4af1-add0-97cdf1feeef7               False
# 14200  7d6a237d-e793-401f-9fac-a11a590526cb               False
# 27451  177a3ef3-9c1f-4e03-b421-849249dcb512               False
# 18568  8b417d9f-2e39-4637-9ca9-e404d11ddc20               False
# 42863  044f71ac-f972-47cf-81cf-6ad35d83a7a5               False
# 29459  32f2d0cc-16fa-43d5-9fdc-5e390b430a93               False
# 19025  9857fae5-fe45-4930-8692-74329cf2bdc3               False
# 14485  9f4dbbd0-36aa-486b-8491-b23a0a9bb5be               False
# 32790  163a53a6-9e99-40bd-a603-37f9504bba2c               False
# 18918  4994a449-b72e-4ef3-b572-fd0f0de8275f               False
#
#        Children_total  Customer_Tenure_Years
# 4569                2                     13
# 24552               1                     11
# 3086                1                     13
# 22617               2                     11
# 27197               4                     11
# 24190               1                     12
# 12156               2                     13
# 8238                3                     13
# 36640               2                     11
# 13839               2                     12
# 6165                3                     13
# 14200               1                     13
# 27451               3                     11
# 18568               3                     12
# 42863               2                     10
# 29459               0                     11
# 19025               2                     13
# 14485               2                     13
# 32790               2                     11
# 18918               3                     13

# %% [markdown]
# # 6. Nº Visitas. Visualizo

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df_customer["NumWebVisitsMonth"])
plt.title("Boxplot de visitas web al mes")
plt.xlabel("Número de visitas web")
plt.show()

# %%
# Visualizo como queda despues de limpieza y transformación

df_customer.info()
df_customer.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Income                 43170 non-null  int64
#  1   Kidhome                43170 non-null  Int64
#  2   Teenhome               43170 non-null  Int64
#  3   Dt_Customer            43170 non-null  datetime64[ns]
#  4   NumWebVisitsMonth      43170 non-null  int64
#  5   ID                     43170 non-null  object
#  6   income_outlier_iqr     43170 non-null  bool
#  7   Children_total         43170 non-null  int64
#  8   Customer_Tenure_Years  43170 non-null  Int64
# dtypes: Int64(3), bool(1), datetime64[ns](1), int64(3), object(1)
# memory usage: 2.8+ MB
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 42349   98960        1         1  2014-01-23                 10
# 6294   131830        2         1  2012-12-05                  8
# 38789   73545        2         1  2014-02-12                 28
# 3712   136923        1         1  2012-08-26                 21
# 1362    68158        1         2  2012-11-23                  5
# 24069  175836        1         2  2013-07-17                 10
# 33040   50256        1         2  2014-02-18                  2
# 6256    11876        1         0  2012-08-19                  7
# 1919    60490        2         1  2012-11-28                 32
# 7802    90729        0         1  2012-12-01                  2
#
#                                          ID  income_outlier_iqr  \
# 42349  52ba4aca-b569-4e7b-8a05-406494b605ae               False
# 6294   c3039348-6925-475a-9bb8-7e6db1431a69               False
# 38789  e6a1f062-7e6f-45e1-84e8-5500f8699bd5               False
# 3712   a52cce74-6488-4b32-9f96-f44cc4b8df00               False
# 1362   90abc78d-75b6-4a69-b40a-b4c9a4bec702               False
# 24069  4007a0d5-da8e-4680-8051-dfcba5bb0adb               False
# 33040  6c490ac9-52af-4b70-9956-b604cdd54e49               False
# 6256   d2323ef6-a56e-41dc-b117-edf980f8c125               False
# 1919   0391aa0a-0c04-4fbe-82af-6429af67b868               False
# 7802   56b56efd-dea6-4bb4-955d-11d780bb24a1               False
#
#        Children_total  Customer_Tenure_Years
# 42349               2                     11
# 6294                3                     12
# 38789               3                     11
# 3712                2                     13
# 1362                3                     12
# 24069               3                     12
# 33040               3                     11
# 6256                1                     13
# 1919                3                     12
# 7802                1                     12

# %% [markdown]
# # ****2º Dataset. Carga de datos. Información****

# %%
df_bank = pd.read_csv("../Data/Raw/bank-additional.csv")

# %%
df_bank. sample(10)
# Out:
#        Unnamed: 0   age            job   marital          education  default  \
# 25269       25391   NaN      housemaid    SINGLE           basic.9y      0.0
# 27013       27157   NaN  self-employed   MARRIED  university.degree      0.0
# 34025       34169  32.0    blue-collar    SINGLE           basic.9y      0.0
# 12853       12950  43.0    blue-collar  DIVORCED           basic.9y      0.0
# 37369       37536  36.0     management   MARRIED           basic.6y      0.0
# 20723       20820  34.0         admin.    SINGLE  university.degree      0.0
# 4478         4575  44.0         admin.   MARRIED  university.degree      0.0
# 11441       11538  41.0    blue-collar   MARRIED           basic.4y      NaN
# 27692       27836  28.0  self-employed    SINGLE  university.degree      0.0
# 34530       34674  42.0    blue-collar   MARRIED           basic.4y      0.0
#
#        housing  loan    contact  duration  ...  emp.var.rate  cons.price.idx  \
# 25269      0.0   0.0   cellular       173  ...          -0.1            93,2
# 27013      0.0   0.0   cellular        89  ...          -0.1            93,2
# 34025      0.0   0.0   cellular       253  ...          -1.8          92,893
# 12853      0.0   0.0   cellular       108  ...           1.4          93,918
# 37369      1.0   1.0   cellular       354  ...          -2.9          92,201
# 20723      1.0   0.0   cellular        67  ...           1.4          93,444
# 4478       0.0   0.0  telephone        10  ...           1.1          93,994
# 11441      1.0   0.0  telephone       174  ...           1.4          94,465
# 27692      0.0   0.0   cellular       296  ...          -1.8          92,843
# 34530      0.0   0.0   cellular       131  ...          -1.8          92,893
#
#        cons.conf.idx euribor3m  nr.employed    y               date latitude  \
# 25269            -42       NaN       5195,8   no     29-agosto-2015   48.189
# 27013            -42     4,021       5195,8   no      13-enero-2017   29.033
# 34025          -46,2     1,281       5099,1   no      23-julio-2019   24.795
# 12853          -42,7     4,962       5228,1   no    15-febrero-2015   37.190
# 37369          -31,4     0,873       5076,2  yes      27-marzo-2016   48.284
# 20723          -36,1     4,965       5228,1   no      10-marzo-2015   42.170
# 4478           -36,4     4,856         5191   no  11-noviembre-2018   39.981
# 11441          -41,8       NaN       5228,1   no   8-noviembre-2017   37.244
# 27692            -50      1,64       5099,1  yes  11-diciembre-2017   30.630
# 34530          -46,2     1,266       5099,1   no       6-abril-2018   28.347
#
#       longitude                                   id_
# 25269   -88.065  a78c581f-0c3c-48d5-97b5-b8d94ba0ae8a
# 27013   -90.045  51ce5aee-f8bd-4351-a7db-aaa90ef2e09c
# 34025  -102.936  f0112bed-bbec-48f0-aed3-bec6740ef2f9
# 12853   -76.364  4d443998-db7c-4194-86ef-46e4079d43e6
# 37369  -115.202  e8c87096-2ff1-4558-aa82-459ee4e0dd9b
# 20723   -76.182  ebee261e-5b14-4061-a3c4-a4ff2becb8d1
# 4478    -81.461  7c28204b-cd77-4795-a7b5-5cc874bc6d20
# 11441   -95.647  bcdd87c7-03df-4239-a481-acdbea47731f
# 27692   -70.634  7b081a2b-a761-4143-a0c5-802d54477545
# 34530   -89.354  94271681-3db7-45cd-8447-1572ae75a215
#
# [10 rows x 24 columns]

# %%
df_bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      43000 non-null  int64
#  1   age             37880 non-null  float64
#  2   job             42655 non-null  object
#  3   marital         42915 non-null  object
#  4   education       41193 non-null  object
#  5   default         34019 non-null  float64
#  6   housing         41974 non-null  float64
#  7   loan            41974 non-null  float64
#  8   contact         43000 non-null  object
#  9   duration        43000 non-null  int64
#  10  campaign        43000 non-null  int64
#  11  pdays           43000 non-null  int64
#  12  previous        43000 non-null  int64
#  13  poutcome        43000 non-null  object
#  14  emp.var.rate    43000 non-null  float64
#  15  cons.price.idx  42529 non-null  object
#  16  cons.conf.idx   43000 non-null  object
#  17  euribor3m       33744 non-null  object
#  18  nr.employed     43000 non-null  object
#  19  y               43000 non-null  object
#  20  date            42752 non-null  object
#  21  latitude        43000 non-null  float64
#  22  longitude       43000 non-null  float64
#  23  id_             43000 non-null  object
# dtypes: float64(7), int64(5), object(12)
# memory usage: 7.9+ MB

# %% [markdown]
# ## Visualizo toda la información, nulos y tipo de dato

# %%
resumen = pd.DataFrame({
    "Non-Null Count": df_bank.notna().sum(),
    "Null Count": df_bank.isna().sum(),
    "Dtype": df_bank.dtypes
})
print(resumen)
# Out:
#                 Non-Null Count  Null Count    Dtype
# Unnamed: 0               43000           0    int64
# age                      37880        5120  float64
# job                      42655         345   object
# marital                  42915          85   object
# education                41193        1807   object
# default                  34019        8981  float64
# housing                  41974        1026  float64
# loan                     41974        1026  float64
# contact                  43000           0   object
# duration                 43000           0    int64
# campaign                 43000           0    int64
# pdays                    43000           0    int64
# previous                 43000           0    int64
# poutcome                 43000           0   object
# emp.var.rate             43000           0  float64
# cons.price.idx           42529         471   object
# cons.conf.idx            43000           0   object
# euribor3m                33744        9256   object
# nr.employed              43000           0   object
# y                        43000           0   object
# date                     42752         248   object
# latitude                 43000           0  float64
# longitude                43000           0  float64
# id_                      43000           0   object

# %% [markdown]
# # Columnas e información
#
# 0. Unnamed:  se puede eliminar
#
# 1. age (float64): edad de la persona.
#
# 2. job (object): profesión.
#
# 3. marital (object): estado civil.
#
# 4. education (object): educación.
#
# 5. default (float64): si el cliente tiene crédito con impago (posibles nulos).
#
# 6. housing (float64): si tiene préstamo hipotecario (posibles nulos).
#
# 7. loan (float64): si tiene préstamo personal (posibles nulos).
#
# 8. contact (object): tipo de contacto.
#
# 9. duration (int64): duración de la llamada/contacto en segundos.
#
# 10. campaign (int64):  número de veces que se ha contactado al cliente.
#
# 11. pdays (int64): días desde el último contacto (999 significa que nunca se contactó).
#
# 12. previous (int64): número de contactos anteriores.
#
# 13. poutcome (object): resultado de campaña de marketing anterior.
#
# 14. emp.var.rate (float64): indicador económico (tasa de variación del empleo).
#
# 15. cons.price.idx (object): indice de precios del consumidor.
#
# 16. cons.conf.idx (object): indice de confianza del consumidor.
#
# 17. euribor3m (object): tasa de interés euríbor a 3 meses.
#
# 18. nr.employed (object): número de empleados (indicador económico).
#
# 19. y (object): variable objetivo (si el cliente contrató o no el producto/servicio).
#
# 20. Date: fecha de interacción con el cliente.
#
# 21. latitude (float64): localización geográfica.
#
# 22. longitude (float64): localización geográfica.
#
# 23. id (object): identificador único del cliente.

# %% [markdown]
# # ****LIMPIEZA Y TRANSFORMACIÓN****

# %% [markdown]
# # 1. Eliminamos columna Unnamed

# %%
df_bank = df_bank.drop(columns=["Unnamed: 0"])

# Comprobar columnas resultantes
print(df_bank.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
#        'nr.employed', 'y', 'date', 'latitude', 'longitude', 'id_'],
#       dtype='object')

# %% [markdown]
# # 2. Columna age, tenemos 12% aprox. de nulos.
# 1. Visualizo: edades entre 30 y 50 años, mediana aprox. 40 años (38), de 18 a 20 años los más jóvenes, mayores apox 70 años. Hay clientes con edades entre los 70 y 100 años.
# 2. Reemplazo nulos por la mediana

# %%
# Visualizo
plt.figure(figsize=(6,4))
sns.boxplot(x=df_bank["age"].dropna())
plt.title("Boxplot de la edad de los clientes")
plt.xlabel("Edad")
plt.show()

# %%
# Reemplazo nulos por mediana 38 años
# Calcular la mediana de la edad (ignorando nulos)
mediana_age = df_bank["age"].median()

# Rellenar los nulos con la mediana
df_bank["age"] = df_bank["age"].fillna(mediana_age)

# Compruebo que ya no hay nulos en la columna age
print("Nulos en edad después de imputar:", df_bank["age"].isna().sum())
print("Mediana usada:", mediana_age)
# Out:
# Nulos en edad después de imputar: 0
# Mediana usada: 38.0

# %%
# visulizo la información de nuevo
resumen = pd.DataFrame({
    "Non-Null Count": df_bank.notna().sum(),
    "Null Count": df_bank.isna().sum(),
    "Dtype": df_bank.dtypes
})
print(resumen)
# Out:
#                 Non-Null Count  Null Count    Dtype
# age                      43000           0  float64
# job                      42655         345   object
# marital                  42915          85   object
# education                41193        1807   object
# default                  34019        8981  float64
# housing                  41974        1026  float64
# loan                     41974        1026  float64
# contact                  43000           0   object
# duration                 43000           0    int64
# campaign                 43000           0    int64
# pdays                    43000           0    int64
# previous                 43000           0    int64
# poutcome                 43000           0   object
# emp.var.rate             43000           0  float64
# cons.price.idx           42529         471   object
# cons.conf.idx            43000           0   object
# euribor3m                33744        9256   object
# nr.employed              43000           0   object
# y                        43000           0   object
# date                     42752         248   object
# latitude                 43000           0  float64
# longitude                43000           0  float64
# id_                      43000           0   object

# %% [markdown]
# # 3. Columna job. Reemplazo nulos por "desconocido".  Convierto a español.

# %%
df_bank['job'] = df_bank['job'].fillna('desconocido')

# Traduzco a español
df_bank['job'] = df_bank['job'].replace({
    'housemaid': 'empleada hogar',
    'services': 'servicios',
    'admin.': 'administrativo',
    'blue-collar': 'obrero',
    'technician': 'técnico',
    'retired': 'jubilado',
    'management': 'directivo',
    'unemployed': 'desempleado',
    'self-employed': 'autónomo',
    'entrepreneur': 'emprendedor',
    'student': 'estudiante',
    'desconocido': 'desconocido'
})


#visualizo categorías únicas

print(df_bank['job'].unique())
# Out:
# ['empleada hogar' 'servicios' 'administrativo' 'obrero' 'técnico'
#  'jubilado' 'directivo' 'desempleado' 'autónomo' 'desconocido'
#  'emprendedor' 'estudiante']

# %% [markdown]
# # 4. Columna Marital. Reemplazo nulos por "desconocido". Convierto todo en minúsculas y quito espacios

# %%
df_bank['marital'] = df_bank['marital'].fillna('desconocido').replace('', 'desconocido')

#visualizo categorías únicas

print(df_bank['marital'].unique())

# Covertimos en minúsculas y quitamos espacios al principio

df_bank['marital'] = df_bank['marital'].str.strip().str.lower()

# Traduzco a español
df_bank['marital'] = df_bank['marital'].replace({
    'married': 'casado',
    'single': 'soltero',
    'divorced': 'divorciado',
    'desconocido': 'desconocido'
})


# vuelvo a visualizar
print(df_bank['marital'].unique())
# Out:
# ['MARRIED' 'SINGLE' 'DIVORCED' 'desconocido']
# ['casado' 'soltero' 'divorciado' 'desconocido']

# %% [markdown]
# # 5. Columna Education. Cambio nulos por "desconocido". Convertimos en minúsculas y quito espacios. Agrupo categorías

# %%
df_bank['education'] = df_bank['education'].str.strip().str.lower()

#cambio nulos por desconocido
df_bank['education'] = df_bank['education'].replace('', 'desconocido').fillna('desconocido')



#agrupo categorías

df_bank['education'] = df_bank['education'].replace({
    'basic.4y': 'basico',
    'basic.6y': 'basico',
    'basic.9y': 'basico',
    'high.school': 'secundaria',
    'university.degree': 'universidad',
    'professional.course': 'profesional',
    'illiterate': 'sin_estudios',
    'desconocido': 'desconocido'
})
#visualizo. Confirmo todo lo hecho anteriormente

print(df_bank['education'].unique())
df_bank.info()
# Out:
# ['basico' 'secundaria' 'profesional' 'desconocido' 'universidad'
#  'sin_estudios']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  float64
#  1   job             43000 non-null  object
#  2   marital         43000 non-null  object
#  3   education       43000 non-null  object
#  4   default         34019 non-null  float64
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(7), int64(4), object(12)
# memory usage: 7.5+ MB

# %% [markdown]
# # 6. Columna default. Cambio los nulos por "desconocido". Convierto valores en string, elimino espacios y todo minuscula. Convierto en si, no o desconocido.

# %%
# Reemplazamos nulos por desconocido
df_bank['default'] = df_bank['default'].fillna('desconocido')

# Convierto valores en string, eliminamos espacios en blanco y en minúscula

df_bank['default'] = df_bank['default'].astype(str).str.strip().str.lower()

# Convierto a objeto

df_bank['default'] = df_bank['default'].replace({
    '0.0': 'no',
    '1.0': 'sí',
    'desconocido': 'desconocido'
})

#reviso resultado
print(df_bank['default'].unique())
df_bank.info()
# Out:
# ['no' 'desconocido' 'sí']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  float64
#  1   job             43000 non-null  object
#  2   marital         43000 non-null  object
#  3   education       43000 non-null  object
#  4   default         43000 non-null  object
#  5   housing         41974 non-null  float64
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(6), int64(4), object(13)
# memory usage: 7.5+ MB

# %% [markdown]
# # 7. Columna housing. Cambio nulos por "desconocido". Convierto valores en string, elimino espacios y minuscula. Convierto en si, no o desconocido.

# %%
# Cambio nulos por desconocido

df_bank['housing'] = df_bank['housing'].fillna('desconocido')

# Convierto valores en string, elimino espacios y minuscula

df_bank['housing'] = df_bank['housing'].astype(str).str.strip().str.lower()

# Convierto a objeto

df_bank['housing'] = df_bank['housing'].replace({
    '0.0': 'no',
    '1.0': 'sí',
    'desconocido': 'desconocido'
})
# visualizo

print(df_bank['housing'].unique())
df_bank.info()
# Out:
# ['no' 'sí' 'desconocido']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  float64
#  1   job             43000 non-null  object
#  2   marital         43000 non-null  object
#  3   education       43000 non-null  object
#  4   default         43000 non-null  object
#  5   housing         43000 non-null  object
#  6   loan            41974 non-null  float64
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(5), int64(4), object(14)
# memory usage: 7.5+ MB

# %% [markdown]
# # 8. Columna loan. Cambio nulos por "desconocido". Convierto valores en string, elimino espacios y minuscula. Convierto en si, no o desconocido.

# %%
df_bank['loan'] = df_bank['loan'].fillna('desconocido')

# Convierto valores en string, elimino espacios y minuscula

df_bank['loan'] = df_bank['loan'].astype(str).str.strip().str.lower()

# Convierto a objeto

df_bank['loan'] = df_bank['loan'].replace({
    '0.0': 'no',
    '1.0': 'sí',
    'desconocido': 'desconocido'
})
# visualizo

print(df_bank['loan'].unique())
df_bank.info()
# Out:
# ['no' 'sí' 'desconocido']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             43000 non-null  float64
#  1   job             43000 non-null  object
#  2   marital         43000 non-null  object
#  3   education       43000 non-null  object
#  4   default         43000 non-null  object
#  5   housing         43000 non-null  object
#  6   loan            43000 non-null  object
#  7   contact         43000 non-null  object
#  8   duration        43000 non-null  int64
#  9   campaign        43000 non-null  int64
#  10  pdays           43000 non-null  int64
#  11  previous        43000 non-null  int64
#  12  poutcome        43000 non-null  object
#  13  emp.var.rate    43000 non-null  float64
#  14  cons.price.idx  42529 non-null  object
#  15  cons.conf.idx   43000 non-null  object
#  16  euribor3m       33744 non-null  object
#  17  nr.employed     43000 non-null  object
#  18  y               43000 non-null  object
#  19  date            42752 non-null  object
#  20  latitude        43000 non-null  float64
#  21  longitude       43000 non-null  float64
#  22  id_             43000 non-null  object
# dtypes: float64(4), int64(4), object(15)
# memory usage: 7.5+ MB

# %% [markdown]
# # 9. Columna contact, traduzco a español. No hay nulos.

# %%
df_bank['contact'] = df_bank['contact'].replace({
    'cellular': 'móvil',
    'telephone': 'teléfono fijo'
})

print(df_bank['contact'].unique())
# Out:
# ['teléfono fijo' 'móvil']

# %% [markdown]
# # 10. Columna duration lo convierto en minutos.

# %%
# Convierto de segundos a minutos
df_bank['duration'] = (df_bank['duration'] / 60).round(2)

print(df_bank['duration'].head())
# Out:
# 0    4.35
# 1    2.48
# 2    3.77
# 3    2.52
# 4    5.12
# Name: duration, dtype: float64

# %% [markdown]
# # 11. Columna pdays, tenemos valores del 1 al 27 que es con contacto,  0 y 999 que entiendo que es sin contacto. Transformo columna en datos contacto o no contacto.

# %%
# Transformamos la columna pdays en 'contacto' / 'no_contacto'
df_bank['pdays'] = df_bank['pdays'].apply(lambda x: 'no_contacto' if x in [0, 999] else 'contacto')

# Revisamos resultado
print(df_bank['pdays'].unique())
print(df_bank['pdays'].value_counts())
# Out:
# ['no_contacto' 'contacto']
# pdays
# no_contacto    41427
# contacto        1573
# Name: count, dtype: int64

# %%
#Visualizo 
df_bank.sample(10)
# Out:
#         age             job  marital    education      default      housing  \
# 10732  38.0          obrero   casado       basico           no           no
# 18684  28.0          obrero   casado       basico  desconocido           sí
# 3880   36.0       directivo   casado       basico           no  desconocido
# 5302   38.0       servicios  soltero   secundaria           no           sí
# 42925  47.0       servicios   casado   secundaria           no           sí
# 1825   39.0       servicios   casado   secundaria  desconocido           no
# 18083  39.0  administrativo  soltero       basico  desconocido           no
# 31351  29.0          obrero   casado       basico           no           sí
# 5273   32.0         técnico  soltero  profesional           no           no
# 29329  31.0          obrero   casado       basico           no           sí
#
#               loan        contact  duration  campaign  ... emp.var.rate  \
# 10732           no  teléfono fijo      0.62         1  ...          1.4
# 18684           no          móvil      0.10         8  ...          1.4
# 3880   desconocido  teléfono fijo      4.75         2  ...          1.1
# 5302            sí  teléfono fijo      6.20         3  ...          1.1
# 42925           no          móvil     10.60         2  ...         -1.8
# 1825            sí  teléfono fijo      2.23         3  ...          1.1
# 18083           sí          móvil      1.57         4  ...          1.4
# 31351           no          móvil      2.33         2  ...         -1.8
# 5273            no  teléfono fijo     11.67         3  ...          1.1
# 29329           no          móvil      0.32         6  ...         -1.8
#
#        cons.price.idx cons.conf.idx  euribor3m nr.employed    y  \
# 10732          94,465         -41,8      4,962      5228,1   no
# 18684          93,918         -42,7        NaN      5228,1   no
# 3880           93,994         -36,4        NaN        5191   no
# 5302           93,994         -36,4        NaN        5191   no
# 42925          93,075         -47,1        NaN      5099,1  yes
# 1825           93,994         -36,4      4,855        5191   no
# 18083          93,918         -42,7      4,963      5228,1   no
# 31351          92,893         -46,2      1,334      5099,1   no
# 5273           93,994         -36,4      4,857        5191   no
# 29329          93,075         -47,1      1,405      5099,1   no
#
#                      date latitude longitude  \
# 10732        13-mayo-2018   37.432  -113.763
# 18684  29-septiembre-2018   44.226  -110.422
# 3880       3-octubre-2017   25.085   -79.604
# 5302      28-octubre-2019   32.767  -100.939
# 42925     19-octubre-2016   33.237   -67.639
# 1825         29-mayo-2017   26.581   -68.298
# 18083   18-diciembre-2015   34.828  -102.851
# 31351       30-junio-2017   43.416   -89.827
# 5273         3-marzo-2015   45.129  -103.818
# 29329       22-julio-2015   24.442  -108.064
#
#                                         id_
# 10732  5826edcb-7331-448a-8718-e41f771b4259
# 18684  da553009-662b-4b6a-87c5-0c9e420ede24
# 3880   f4a65159-2c85-4041-ba4c-6c385dbfece1
# 5302   b65505ea-3aea-46a8-bc13-ee7d341af873
# 42925  d0db64d8-6ccf-4a26-b8b0-85d595a5af5a
# 1825   5b3a511b-33f0-4b6a-b44b-a53e24a209ee
# 18083  6794c002-9b5c-453b-abc1-283451675f17
# 31351  5ccc18c3-8f51-470a-bac0-7a4db628ad6d
# 5273   39d05e4d-256c-45fb-a112-ad2b255c882c
# 29329  37b85b78-e108-411a-8d8b-e3d733cc217c
#
# [10 rows x 23 columns]

# %% [markdown]
# # 12. Columna poutcome, tenemos 3 valores. Traduzco.

# %%
# Normalizo a minusculas
df_bank['poutcome'] = df_bank['poutcome'].str.strip().str.lower()

df_bank['poutcome'] = df_bank['poutcome'].replace({
    'success': 'éxito',
    'failure': 'fracaso',
    'nonexistent': 'inexistente'
})

# Reviso resultado
print(df_bank['poutcome'].unique())
print(df_bank['poutcome'].value_counts())
# Out:
# ['inexistente' 'fracaso' 'éxito']
# poutcome
# inexistente    37103
# fracaso         4461
# éxito           1436
# Name: count, dtype: int64

# %% [markdown]
# # 13. Columna emp. var. rate, lo transformo en categorías de tendencia.

# %%
# Transformo
df_bank['emp.var.rate'] = df_bank['emp.var.rate'].apply(
    lambda x: 'caída empleo' if x < 0 else 'crecimiento empleo'
)


#Visualizo
df_bank.sample(10)
# Out:
#         age             job     marital    education      default housing  \
# 2774   41.0  administrativo     soltero  universidad           no      no
# 4359   29.0      estudiante     soltero  universidad           no      sí
# 10239  34.0     emprendedor     soltero  profesional           no      sí
# 12326  42.0          obrero     soltero       basico  desconocido      no
# 31136  38.0          obrero     soltero       basico           no      sí
# 5943   45.0          obrero      casado       basico  desconocido      sí
# 33030  38.0          obrero     soltero       basico           no      sí
# 2492   47.0       servicios      casado   secundaria  desconocido      no
# 41385  52.0         técnico      casado       basico           no      no
# 13025  38.0          obrero  divorciado       basico           no      sí
#
#       loan        contact  duration  campaign  ...        emp.var.rate  \
# 2774    no  teléfono fijo      4.42         2  ...  crecimiento empleo
# 4359    no  teléfono fijo     17.37        17  ...  crecimiento empleo
# 10239   no  teléfono fijo      2.27         8  ...  crecimiento empleo
# 12326   no          móvil      0.82         6  ...  crecimiento empleo
# 31136   no          móvil      3.38         2  ...        caída empleo
# 5943    no  teléfono fijo      4.05         2  ...  crecimiento empleo
# 33030   no          móvil     20.05         1  ...        caída empleo
# 2492    sí  teléfono fijo      1.15        11  ...  crecimiento empleo
# 41385   no  teléfono fijo      1.62         1  ...  crecimiento empleo
# 13025   no          móvil      3.45         3  ...  crecimiento empleo
#
#        cons.price.idx cons.conf.idx euribor3m nr.employed    y  \
# 2774           93,994         -36,4     4,859        5191   no
# 4359           93,994         -36,4     4,856        5191   no
# 10239          94,465         -41,8       NaN      5228,1   no
# 12326          93,918         -42,7      4,96      5228,1   no
# 31136          92,893         -46,2     1,334      5099,1   no
# 5943           93,994         -36,4     4,857        5191   no
# 33030          92,893         -46,2     1,291      5099,1  yes
# 2492           93,994         -36,4     4,856        5191   no
# 41385          93,994         -36,4       NaN        5191   no
# 13025          93,918         -42,7     4,962      5228,1   no
#
#                    date latitude longitude  \
# 2774     1-febrero-2018   39.115  -111.407
# 4359    14-febrero-2016   26.424   -87.637
# 10239   16-octubre-2019   32.071  -114.344
# 12326  3-noviembre-2016   48.019  -112.924
# 31136    2-octubre-2016   33.659  -114.879
# 5943      14-junio-2019   26.382   -72.479
# 33030      23-mayo-2016   30.252   -69.932
# 2492      16-abril-2017   37.746   -68.100
# 41385      6-abril-2017   44.335   -96.680
# 13025   24-febrero-2017   35.347  -123.523
#
#                                         id_
# 2774   a0a188c2-af0e-41e5-bfed-6a74adbb5f35
# 4359   6f176697-8bb7-4b8e-be25-973edf7c403f
# 10239  be1652f9-563a-47a1-b6ea-a785f0896819
# 12326  b62e90ed-4a13-4119-ba79-5a3eee016632
# 31136  537bfa86-d5e5-4982-9611-ceb8b96740a6
# 5943   9d86d9d0-60c1-4f10-b9ec-49988b347f18
# 33030  65119cf7-a470-4995-a93f-aac58140d9c3
# 2492   c6d37529-ae25-4fa7-bc67-0b72849ca1d1
# 41385  0d2b5975-6105-4a3b-94fd-5c0267a15350
# 13025  16b4d625-9f32-4a82-96eb-496a47c8410b
#
# [10 rows x 23 columns]

# %% [markdown]
# # 14. Columna cons.price.idx , primero cuento cada valor (nulos). Como nos da el 1.1% de nulos los reemplazo por la mediana

# %%
# Contar cuántos valores vacíos hay

print(df_bank['cons.price.idx'].value_counts(dropna=False))
# Out:
# cons.price.idx
# 93,994    7938
# 93,918    6937
# 92,893    5985
# 93,444    5349
# 94,465    4522
# 93,2      3731
# 93,075    2552
# 92,201     803
# 92,963     742
# NaN        471
# 92,431     471
# 92,649     375
# 94,215     320
# 94,199     316
# 92,843     298
# 92,379     274
# 93,369     271
# 94,027     242
# 94,055     236
# 93,876     224
# 94,601     212
# 92,469     184
# 92,713     179
# 93,749     179
# 94,767     130
# 93,798      48
# 92,756      11
# Name: count, dtype: int64

# %%
# Reemplazo comas por puntos y convierto a numérico
df_bank['cons.price.idx'] = df_bank['cons.price.idx'].astype(str).str.replace(',', '.')
df_bank['cons.price.idx'] = pd.to_numeric(df_bank['cons.price.idx'], errors='coerce')


# Calcular mediana
mediana_precio = df_bank['cons.price.idx'].median()

# Rellenar vacíos con la mediana
df_bank['cons.price.idx'] = df_bank['cons.price.idx'].fillna(mediana_precio)

# Revisar que ya no haya vacíos
print(df_bank['cons.price.idx'].isna().sum())


# verifico

# 1. Confirmo que ya no quedan vacíos
print("Nulos en cons.price.idx:", df_bank['cons.price.idx'].isna().sum())

# 2. Estadísticas descriptivas
print("\nEstadísticas de cons.price.idx:")
print(df_bank['cons.price.idx'].describe())

# 3. Valores únicos más frecuentes
print("\nValores más frecuentes:")
print(df_bank['cons.price.idx'].value_counts().head(10))
# Out:
# 0
# Nulos en cons.price.idx: 0
#
# Estadísticas de cons.price.idx:
# count    43000.000000
# mean        93.576134
# std          0.576652
# min         92.201000
# 25%         93.075000
# 50%         93.749000
# 75%         93.994000
# max         94.767000
# Name: cons.price.idx, dtype: float64
#
# Valores más frecuentes:
# cons.price.idx
# 93.994    7938
# 93.918    6937
# 92.893    5985
# 93.444    5349
# 94.465    4522
# 93.200    3731
# 93.075    2552
# 92.201     803
# 92.963     742
# 93.749     650
# Name: count, dtype: int64

# %% [markdown]
# # 15. Columna cons.conf.idx, con los varoles - transformo en "confianza media", "baja confianza" y "alta confianza".

# %%
# Aseguro que los valores son numéricos (convertimos coma a punto si hace falta)
df_bank['cons.conf.idx'] = df_bank['cons.conf.idx'].astype(str).str.replace(',', '.')
df_bank['cons.conf.idx'] = pd.to_numeric(df_bank['cons.conf.idx'], errors='coerce')

# Transformo directamente en categorías
df_bank['cons.conf.idx'] = pd.qcut(df_bank['cons.conf.idx'], 
                                   q=3, 
                                   labels=['baja confianza', 'confianza media', 'alta confianza'])

# Reviso
print(df_bank['cons.conf.idx'].unique())
print(df_bank['cons.conf.idx'].value_counts(normalize=True) * 100)
# Out:
# ['confianza media', 'baja confianza', 'alta confianza']
# Categories (3, object): ['baja confianza' < 'confianza media' < 'alta confianza']
# cons.conf.idx
# confianza media    43.072093
# baja confianza     37.904651
# alta confianza     19.023256
# Name: proportion, dtype: float64

# %% [markdown]
# # 16. Columna Euribor3m.  Cuento nulos = 21.53%. Reemplazo nulos por "euribor desconocido". Creo categorías; euribor bajo, euribor medio, euribor alto y ya creada euribor desconocido.

# %%
# Cuento nulos
nulos_euribor = df_bank['euribor3m'].isna().sum()
total_registros = len(df_bank)

print(f"Nulos en euribor3m: {nulos_euribor}")
print(f"Total de registros: {total_registros}")
print(f"Porcentaje de nulos: {nulos_euribor / total_registros * 100:.2f}%")
# Out:
# Nulos en euribor3m: 9256
# Total de registros: 43000
# Porcentaje de nulos: 21.53%

# %%
# Reemplazo nulos por "euribor desconocido"
df_bank['euribor3m'] = df_bank['euribor3m'].fillna('euribor desconocido')

# Reviso resultado
print(df_bank['euribor3m'].value_counts(dropna=False))
# Out:
# euribor3m
# euribor desconocido    9256
# 4,857                  2287
# 4,962                  2124
# 4,963                  2019
# 4,961                  1594
#                        ...
# 5,045                     1
# 4,921                     1
# 0,956                     1
# 0,894                     1
# 0,953                     1
# Name: count, Length: 310, dtype: int64

# %%
# Separo los nulos ya marcados como 'euribor desconocido'
mask_numericos = df_bank['euribor3m'] != 'euribor desconocido'

# Convierto los valores numéricos a float corrigiendo la coma decimal
df_bank.loc[mask_numericos, 'euribor3m'] = (
    df_bank.loc[mask_numericos, 'euribor3m']
    .astype(str)            # me aseguro de que son strings
    .str.replace(',', '.')  # cambio coma por punto
    .astype(float)          # convierto a float
)

# Aplico qcut a esos valores numéricos
df_bank.loc[mask_numericos, 'euribor3m'] = pd.qcut(
    df_bank.loc[mask_numericos, 'euribor3m'],
    q=3,
    labels=['euribor bajo', 'euribor medio', 'euribor alto']
)

# Reviso
print(df_bank['euribor3m'].unique())
print(df_bank['euribor3m'].value_counts())
# Out:
# ['euribor medio' 'euribor desconocido' 'euribor alto' 'euribor bajo']
# euribor3m
# euribor bajo           11671
# euribor alto           11157
# euribor medio          10916
# euribor desconocido     9256
# Name: count, dtype: int64

# %% [markdown]
# # 17. Columna y. No hay nulos. Traduzo

# %%
# Traduzco 
df_bank['y'] = df_bank['y'].map({'yes': 'Sí', 'no': 'No'})

# Verifico
print(df_bank['y'].value_counts())
# Out:
# y
# No    38156
# Sí     4844
# Name: count, dtype: int64

# %% [markdown]
# # 18. Columna date. Hay nulos, un 0,58%. Dado el bajo porcentaje y para no distorsionar el análisis descriptivo posterior, decidí eliminarlos del dataset. Doy formato a fecha. Creo columnas: año y mes. Creo columna con nombre de mes (string) y la convierto en categórica ordenada

# %%
# Veo cuantos nulos
df_bank['date'].isna().sum(), df_bank['date'].isna().mean() * 100
# Out:
# (np.int64(248), np.float64(0.5767441860465117))

# %%
# Normalizo vacíos para que cuenten como nulos
df_bank['date'] = df_bank['date'].replace(
    to_replace=[r'^\s*$', 'NA', 'NaN', 'nan', 'NULL', 'None', 'NaT'],
    value=pd.NA,
    regex=True
)

# Conteo antes
antes_filas = len(df_bank)
n_nulos = df_bank['date'].isna().sum()
print(f"Nulos en 'date' antes de eliminar: {n_nulos}")

# Elimino filas con date nulo
df_bank = df_bank.dropna(subset=['date']).reset_index(drop=True)

# Verificación
despues_filas = len(df_bank)
eliminadas = antes_filas - despues_filas
print(f"Filas eliminadas: {eliminadas}")
print(f"Nulos restantes en 'date': {df_bank['date'].isna().sum()}")
print(f"Shape actual: {df_bank.shape}")
# Out:
# Nulos en 'date' antes de eliminar: 248
# Filas eliminadas: 248
# Nulos restantes en 'date': 0
# Shape actual: (42752, 23)

# %%
# Normalizo y parseo 'date'  (formato día/mes/año con meses en español)
s = (df_bank['date'].astype(str)
                  .str.lower()
                  .str.replace('\u00a0', ' ', regex=False)      # NBSP → espacio normal
                  .str.replace(r'\s*-\s*', '-', regex=True)      # " - " → "-"
                  .str.replace(r'\s*/\s*', '/', regex=True)      # " / " → "/"
                  .str.strip())

meses = {
    'enero':'1','febrero':'2','marzo':'3','abril':'4','mayo':'5','junio':'6',
    'julio':'7','agosto':'8','septiembre':'9','setiembre':'9',
    'octubre':'10','noviembre':'11','diciembre':'12'
}
for m, n in meses.items():
    s = s.replace(fr'-{m}-', f'-{n}-', regex=True)
    s = s.replace(fr'/{m}/', f'/{n}/', regex=True)

df_bank['date'] = pd.to_datetime(s, dayfirst=True, errors='coerce')

# Chequeo rápido
print(df_bank['date'].dtype, " | NaT:", df_bank['date'].isna().sum())
# Out:
# datetime64[ns]  | NaT: 0

# %%
#Creo columnas, año y mes.
df_bank['year']  = df_bank['date'].dt.year
df_bank['month'] = df_bank['date'].dt.month            # 1–12

# %%
# Creo columna con nombre de mes (string) y la convierto en categórica ordenada
meses = {1:'enero',2:'febrero',3:'marzo',4:'abril',5:'mayo',6:'junio',
         7:'julio',8:'agosto',9:'septiembre',10:'octubre',11:'noviembre',12:'diciembre'}
orden = list(meses.values())
df_bank['month_name'] = df_bank['month'].map(meses)
df_bank['month_name'] = pd.Categorical(df_bank['month_name'], categories=orden, ordered=True)

# %% [markdown]
# # 19. Columnas latitude y longitude. Aseguro tipo numérico, chequeo.

# %%
# Aseguro tipo numérico
df_bank['latitude']  = pd.to_numeric(df_bank['latitude'], errors='coerce')
df_bank['longitude'] = pd.to_numeric(df_bank['longitude'], errors='coerce')

# Chequeos de rango geográfico
print("Lat fuera de [-90,90]:",  (~df_bank['latitude'].between(-90, 90)).sum())
print("Lon fuera de [-180,180]:", (~df_bank['longitude'].between(-180,180)).sum())
# Out:
# Lat fuera de [-90,90]: 0
# Lon fuera de [-180,180]: 0

# %%
# Busco ciudad/país para cada par (lat, lon)
coords = list(zip(df_bank['latitude'].values, df_bank['longitude'].values))
matches = rg.search(coords)   # devuelve lista de dicts: name, admin1, admin2, cc, lat, lon

# Vuelco resultados al DataFrame
df_bank['city']         = [m['name']   for m in matches]   # ciudad más cercana
df_bank['region']       = [m['admin1'] for m in matches]   # estado/provincia
df_bank['country_code'] = [m['cc']     for m in matches]   # código ISO-2

# Código ISO-2 : nombre de país
code2name = {c.alpha_2: c.name for c in pycountry.countries}
df_bank['country'] = df_bank['country_code'].map(code2name).fillna(df_bank['country_code'])

# Vistazo rápido
df_bank[['latitude','longitude','city','region','country']].head()
# Out:
# Loading formatted geocoded file...
#    latitude  longitude          city        region        country
# 0    41.495    -71.233  Newport East  Rhode Island  United States
# 1    34.601    -83.923     Dahlonega       Georgia  United States
# 2    34.939    -94.847        Wister      Oklahoma  United States
# 3    49.041    -70.308      Saguenay        Quebec         Canada
# 4    38.033   -104.463        Pueblo      Colorado  United States

# %% [markdown]
# # 20. Columna id. Comprobar si hay dupliados. No hay duplicados.

# %%
duplicados = df_bank['id_'].duplicated().sum()
print(f"Número de IDs duplicados: {duplicados}")
# Out:
# Número de IDs duplicados: 0

# %% [markdown]
# # 21. Visualizo lo hecho

# %%
display(df_bank)
# Out:
#         age             job  marital    education      default housing loan  \
# 0      38.0  empleada hogar   casado       basico           no      no   no
# 1      57.0       servicios   casado   secundaria  desconocido      no   no
# 2      37.0       servicios   casado   secundaria           no      sí   no
# 3      40.0  administrativo   casado       basico           no      no   no
# 4      56.0       servicios   casado   secundaria           no      no   sí
# ...     ...             ...      ...          ...          ...     ...  ...
# 42747  38.0  administrativo   casado  universidad           no      no   no
# 42748  34.0         técnico   casado  profesional           no      sí   sí
# 42749  38.0          obrero  soltero       basico           no      sí   no
# 42750  38.0  administrativo   casado  universidad  desconocido      no   no
# 42751  38.0     desempleado  soltero  universidad           no      no   sí
#
#              contact  duration  campaign  ... latitude  longitude  \
# 0      teléfono fijo      4.35         1  ...   41.495    -71.233
# 1      teléfono fijo      2.48         1  ...   34.601    -83.923
# 2      teléfono fijo      3.77         1  ...   34.939    -94.847
# 3      teléfono fijo      2.52         1  ...   49.041    -70.308
# 4      teléfono fijo      5.12         1  ...   38.033   -104.463
# ...              ...       ...       ...  ...      ...        ...
# 42747          móvil     10.30         2  ...   38.147   -105.582
# 42748          móvil      0.70         7  ...   49.235   -112.201
# 42749          móvil      6.52         2  ...   40.679   -120.015
# 42750          móvil     11.23         3  ...   27.772   -117.518
# 42751          móvil      1.73         2  ...   41.146   -105.026
#
#                                         id_  year  month  month_name  \
# 0      089b39d8-e4d0-461b-87d4-814d71e0e079  2019      8      agosto
# 1      e9d37224-cb6f-4942-98d7-46672963d097  2016      9  septiembre
# 2      3f9f49b5-e410-4948-bf6e-f9244f04918b  2019      2     febrero
# 3      9991fafb-4447-451a-8be2-b0df6098d13e  2015     11   noviembre
# 4      eca60b76-70b6-4077-80ba-bc52e8ebb0eb  2017      1       enero
# ...                                     ...   ...    ...         ...
# 42747  4eed05de-2a98-4227-b488-32122009b638  2015     10     octubre
# 42748  0f0aca88-4088-4fe2-905f-44fb675d9493  2018      3       marzo
# 42749  cadadd4b-7ee5-4019-b13a-ca01bb67ca5b  2016      9  septiembre
# 42750  5f432048-d515-4bb5-9c94-62db451f88d4  2019      9  septiembre
# 42751  993bbbd6-4dbc-4a40-a408-f91f8462bee6  2019     11   noviembre
#
#                              city           region country_code        country
# 0                    Newport East     Rhode Island           US  United States
# 1                       Dahlonega          Georgia           US  United States
# 2                          Wister         Oklahoma           US  United States
# 3                        Saguenay           Quebec           CA         Canada
# 4                          Pueblo         Colorado           US  United States
# ...                           ...              ...          ...            ...
# 42747                  Westcliffe         Colorado           US  United States
# 42748                     Raymond          Alberta           CA         Canada
# 42749                  Janesville       California           US  United States
# 42750  Luis Rodriguez (El Vergel)  Baja California           MX         Mexico
# 42751                    Cheyenne          Wyoming           US  United States
#
# [42752 rows x 30 columns]

# %% [markdown]
# # ****SINTESIS DE LIMPIEZA Y TRANSFORMACIÓN DATASET CUSTOMER****
#
# *   Tenemos 43170 filas y 8 columnas.
#
# *	Elimino Unnamed, no aporta ninguna información.
#
# *	No tenemos duplicados en ID
#
# *	Distribución de Income: no hay outliers. Valores reales min. de 5841 y max. de 180802. Entiendo que son dólares por geolocalización. Cuartiles de ingresos entre 50K y 130K. mediana aprox. 93K.
#
# *   Distribución de Kidhome y Teenhome: hijos en el hogar. Unifico creando columna con total de hijos.
#
# *	Antigüedad del cliente: creo columna.
#
# *  Nº de visitas, sin outliers.

# %%
# Visualizo
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)


print(f"Dataset: df_customer | Filas x columnas: {df_customer.shape[0]} x {df_customer.shape[1]}")
display(df_customer.sample(10, random_state=42))
# Out:
# Dataset: df_customer | Filas x columnas: 43170 x 9
#        Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 1388   101609        0         1  2012-09-15                 28
# 13774  148697        2         0  2012-12-16                 13
# 38232   89453        1         1  2014-11-13                 27
# 32348   69848        2         1  2014-07-08                 11
# 21194  178845        0         2  2013-03-26                 32
# 9831   167255        0         2  2012-11-14                 21
# 21721   77786        0         1  2013-08-24                 14
# 2875    76052        0         2  2012-06-13                  8
# 36349   47908        0         2  2014-12-07                  3
# 13561   38855        0         2  2012-07-12                 20
#
#                                          ID  income_outlier_iqr  \
# 1388   dbdb1791-c3cb-4295-99c4-3f0b25e6ba87               False
# 13774  856b9970-3836-4131-8354-2d9ec1c4dd06               False
# 38232  75896b56-e02a-4b00-a783-eee193f14dcb               False
# 32348  16294fa2-c18b-46dc-9db5-b9f3bd5c24ef               False
# 21194  8aeee39f-06b6-47a3-af9c-90c484345623               False
# 9831   b398666a-632c-43ec-b639-cc68ae473475               False
# 21721  b3c81e3b-ac9a-4a25-a588-13cc29bfcb67               False
# 2875   388ae0fb-9ce6-4759-86b0-57a5cd3d36ac               False
# 36349  4c6caae8-4292-4c9a-b488-8d795820772b               False
# 13561  f2dbbc63-0880-4ccb-a004-4f803a3a7e29               False
#
#        Children_total  Customer_Tenure_Years
# 1388                1                     13
# 13774               2                     12
# 38232               2                     10
# 32348               3                     11
# 21194               2                     12
# 9831                2                     12
# 21721               1                     12
# 2875                2                     13
# 36349               2                     10
# 13561               2                     13

# %% [markdown]
# # ****SINTESIS DE LIMPIEZA Y TRANSFORMACIÓN DATASET BANK****
#
# 0. Unnamed:  eliminamos, no aporta valor.
#
# 1. age (float64): edad de la persona. Tenemos aprox.12% nulos. Imputo mediana en nulos.
#
# 2. job (object): profesión. Transformo los nulos por "desconocido". Traduzco.
#
# 3. marital (object): estado civil. Transformo los nulos por "desconocido". Traduzco. Minúscula.
#
# 4. education (object): educación. Convierto en minúscula, quito espacios. Transformo nulos en "desconocido". Agrupo por categorías.
#
# 5. default (float64): si el cliente tiene crédito con impago. Cambio nulos por "desconocido". Convierto valores en string, elimino espacios, todo minúsculas. Convierto si, no o desconocido.
#
# 6. housing (float64): si tiene préstamo hipotecario. Cambio nulos por desconocido. Convierto valores en string, elimino espacios y todo en minúscula. Convierto en si, no o desconocido.
#
# 7. loan (float64): si tiene préstamo personal (posibles nulos). Cambio nulos por desconocido. Convierto valores en string, elimino espacios y todo en minúscula. Convierto en si, no o desconocido.
#
# 8. contact (object): tipo de contacto. Traduzco.
#
# 9. duration (int64): duración de la llamada/contacto en segundos. Covierto en minutos.
#
# 10. campaign (int64):  número de veces que se ha contactado al cliente. No transformo, esta correcta.
#
# 11. pdays (int64): días desde el último contacto (999 significa que nunca se contactó). Transformo en "contacto" o "no contacto".
#
# 12. previous (int64): número de contactos anteriores. Dejo como esta.
#
# 13. poutcome (object): resultado de campaña de marketing anterior. Traduzco a español, 3 valores.
#
# 14. emp.var.rate (float64): indicador económico (tasa de variación del empleo). Creo categorías de tendencia. Transformo columna.
#
# 15. cons.price.idx (object): indice de precios del consumidor. Reemplazo nulos por la madiana. Nulos 1.1%.
#
# 16. cons.conf.idx (object): indice de confianza del consumidor. Con los valores negativos transformo en "confianza media", "baja confianza" y "alta confianza"
#
# 17. euribor3m (object): tasa de interés euríbor a 3 meses. Cuento nulos = 21.53%. Reemplazo nulos por "euribor desconocido". Creo categorías; euribor bajo, euribor medio, euribor alto y ya creada euribor desconocido.
#
# 18. nr.employed (object): número de empleados (indicador económico). La dejamos como esta, no hay nulos.
#
# 19. y (object): variable objetivo (si el cliente contrató o no el producto/servicio). No hay nulos. Traduzco.
#
# 20. Date: fecha de interacción con el cliente. Hay 0.58% nulos, decido eliminar. Doy formato a fecha. Creo columnas mes y año. Añado columna con string mes.
#
# 21. latitude  y longitud (float64): localización geográfica. Instalo e importo librerias de geocodificación, añado columnas con información de geolocacización.
#
# 23. Comprabamos que no hay duplicados en ID, identificador único.

# %%
#Visualizo
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)



print(f"\nDataset: df_bank | Filas x columnas: {df_bank.shape[0]} x {df_bank.shape[1]}")
display(df_bank.sample(10, random_state=42))
# Out:
# Dataset: df_bank | Filas x columnas: 42752 x 30
#         age             job     marital    education      default housing  \
# 5567   51.0       servicios     soltero   secundaria  desconocido      no
# 17126  28.0          obrero     soltero       basico           no      no
# 42356  21.0      estudiante     soltero  desconocido           no      no
# 18806  43.0  administrativo     soltero  universidad           no      sí
# 22098  47.0          obrero      casado       basico           no      no
# 9845   28.0         técnico     soltero  universidad  desconocido      no
# 10755  38.0          obrero      casado       basico  desconocido      sí
# 21720  38.0         técnico     soltero  universidad           no      no
# 2813   31.0       servicios      casado   secundaria           no      no
# 7671   54.0       servicios  divorciado   secundaria           no      no
#
#       loan        contact  duration  campaign        pdays  previous  \
# 5567    no  teléfono fijo      0.75         4  no_contacto         0
# 17126   no          móvil     22.82         9  no_contacto         0
# 42356   no  teléfono fijo      3.67         7  no_contacto         1
# 18806   no          móvil     13.95         2  no_contacto         0
# 22098   sí          móvil      4.57         3  no_contacto         0
# 9845    no  teléfono fijo      5.90        17  no_contacto         0
# 10755   no  teléfono fijo      0.68         1  no_contacto         0
# 21720   no          móvil      3.50         1  no_contacto         0
# 2813    no  teléfono fijo      3.87         1  no_contacto         0
# 7671    no  teléfono fijo      1.88         3  no_contacto         0
#
#           poutcome        emp.var.rate  cons.price.idx    cons.conf.idx  \
# 5567   inexistente  crecimiento empleo          93.994  confianza media
# 17126  inexistente  crecimiento empleo          93.918   baja confianza
# 42356      fracaso        caída empleo          93.749  confianza media
# 18806  inexistente  crecimiento empleo          93.444   alta confianza
# 22098  inexistente  crecimiento empleo          93.444   alta confianza
# 9845   inexistente  crecimiento empleo          94.465  confianza media
# 10755  inexistente  crecimiento empleo          94.465  confianza media
# 21720  inexistente  crecimiento empleo          93.444   alta confianza
# 2813   inexistente  crecimiento empleo          93.994  confianza media
# 7671   inexistente  crecimiento empleo          94.465  confianza media
#
#                  euribor3m nr.employed   y       date  latitude  longitude  \
# 5567   euribor desconocido        5191  No 2017-06-06    46.080    -81.344
# 17126  euribor desconocido      5228,1  Sí 2019-05-31    28.984    -92.559
# 42356         euribor bajo      4991,6  No 2017-01-10    41.653    -90.064
# 18806  euribor desconocido      5228,1  Sí 2015-10-18    31.659    -82.900
# 22098         euribor alto      5228,1  No 2017-08-01    26.768    -96.529
# 9845          euribor alto      5228,1  No 2015-03-15    27.044   -105.578
# 10755         euribor alto      5228,1  No 2018-10-25    33.257    -75.828
# 21720         euribor alto      5228,1  No 2018-09-23    37.230   -123.286
# 2813         euribor medio        5191  No 2018-01-31    25.436    -85.211
# 7671         euribor medio      5228,1  No 2018-02-28    48.272   -105.200
#
#                                         id_  year  month  month_name  \
# 5567   fb1bb117-645d-4108-b85c-25b34b362418  2017      6       junio
# 17126  83514814-302a-4844-b106-606ee0cb9f47  2019      5        mayo
# 42356  54aa2651-74cc-4d9c-8dc3-131818c86b6e  2017      1       enero
# 18806  65c1b1eb-c0e5-4ea8-9495-e50bb2d31994  2015     10     octubre
# 22098  3fcb3a56-d6b0-4391-ba3b-50d21f1e13bc  2017      8      agosto
# 9845   e3c7cb47-7fd3-4a35-b550-acf09a17f1d6  2015      3       marzo
# 10755  ce708e44-eacd-458f-86df-43276f07a32c  2018     10     octubre
# 21720  dfd76b3f-f413-43e5-a72f-82a8e72f0a8d  2018      9  septiembre
# 2813   6bea135c-c4e0-47d0-b434-fd98a20f9926  2018      1       enero
# 7671   48d97e54-0c1e-47e3-89d7-21f0cc643a33  2018      2     febrero
#
#                      city          region country_code        country
# 5567             Espanola         Ontario           CA         Canada
# 17126             Gueydan       Louisiana           US  United States
# 42356                Erie        Illinois           US  United States
# 18806             Broxton         Georgia           US  United States
# 22098  South Padre Island           Texas           US  United States
# 9845   Hidalgo del Parral       Chihuahua           MX         Mexico
# 10755      Harkers Island  North Carolina           US  United States
# 21720          Moss Beach      California           US  United States
# 2813         La Esperanza   Pinar del Rio           CU           Cuba
# 7671           Wolf Point         Montana           US  United States

# %% [markdown]
# ### Guardo Datasets limpios y transformados ###

# %%
here = Path.cwd()
data_dir = next((d for d in [
    here / "Data", here.parent / "Data", here / "data", here.parent / "data"
] if d.exists()), None)

if data_dir is None:
    raise FileNotFoundError(f"No encuentro 'Data' desde {here}")

outdir = data_dir / "Output"
outdir.mkdir(parents=True, exist_ok=True)

df_customer.to_csv(outdir / "customer_clean.csv", index=False, encoding="utf-8")
df_bank.to_csv(outdir / "bank_clean.csv", index=False, encoding="utf-8")

# %% [markdown]
# ## CARGAMOS ARCHIVOS LIMPIOS Y TRANSFORMADOS

# %%
def find_output_dir(start: Path, levels_up: int = 5):
    p = start
    for _ in range(levels_up):
        cand = p / "Data" / "Output"
        if cand.exists():
            return cand
        p = p.parent
    raise FileNotFoundError("No encontré 'Data/Output' subiendo niveles desde " + str(start))

output_dir = find_output_dir(Path.cwd())
print("Output:", output_dir.resolve())

df_customer = pd.read_csv(output_dir / "customer_clean.csv")
df_bank     = pd.read_csv(output_dir / "bank_clean.csv")

print("Customer:", df_customer.shape)
print("Bank:", df_bank.shape)
# Out:
# Output: C:\Users\Propietario\Desktop\PROYECTO_PYTHON_FOR_DATA\PROYECTO_EDA_PYTHON\Data\Output
# Customer: (43170, 9)
# Bank: (42752, 30)

# %% [markdown]
# ## VISION GENERAL

# %%
print("Bank dataset:", df_bank.shape)
print("Customer dataset:", df_customer.shape)

print("\nPrimeras filas de Bank:")
display(df_bank.head(10))

print("\nPrimeras filas de Customer:")
display(df_customer.head(10))
# Out:
# Bank dataset: (42752, 30)
# Customer dataset: (43170, 9)
#
# Primeras filas de Bank:
#     age             job  marital    education      default housing loan  \
# 0  38.0  empleada hogar   casado       basico           no      no   no
# 1  57.0       servicios   casado   secundaria  desconocido      no   no
# 2  37.0       servicios   casado   secundaria           no      sí   no
# 3  40.0  administrativo   casado       basico           no      no   no
# 4  56.0       servicios   casado   secundaria           no      no   sí
# 5  45.0       servicios   casado       basico  desconocido      no   no
# 6  59.0  administrativo   casado  profesional           no      no   no
# 7  38.0          obrero   casado  desconocido  desconocido      no   no
# 8  24.0         técnico  soltero  profesional           no      sí   no
# 9  25.0       servicios  soltero   secundaria           no      sí   no
#
#          contact  duration  campaign        pdays  previous     poutcome  \
# 0  teléfono fijo      4.35         1  no_contacto         0  inexistente
# 1  teléfono fijo      2.48         1  no_contacto         0  inexistente
# 2  teléfono fijo      3.77         1  no_contacto         0  inexistente
# 3  teléfono fijo      2.52         1  no_contacto         0  inexistente
# 4  teléfono fijo      5.12         1  no_contacto         0  inexistente
# 5  teléfono fijo      3.30         1  no_contacto         0  inexistente
# 6  teléfono fijo      2.32         1  no_contacto         0  inexistente
# 7  teléfono fijo      3.62         1  no_contacto         0  inexistente
# 8  teléfono fijo      6.33         1  no_contacto         0  inexistente
# 9  teléfono fijo      0.83         1  no_contacto         0  inexistente
#
#          emp.var.rate  cons.price.idx    cons.conf.idx            euribor3m  \
# 0  crecimiento empleo          93.994  confianza media        euribor medio
# 1  crecimiento empleo          93.994  confianza media  euribor desconocido
# 2  crecimiento empleo          93.994  confianza media        euribor medio
# 3  crecimiento empleo          93.994  confianza media  euribor desconocido
# 4  crecimiento empleo          93.994  confianza media  euribor desconocido
# 5  crecimiento empleo          93.994  confianza media        euribor medio
# 6  crecimiento empleo          93.994  confianza media        euribor medio
# 7  crecimiento empleo          93.994  confianza media        euribor medio
# 8  crecimiento empleo          93.994  confianza media        euribor medio
# 9  crecimiento empleo          93.994  confianza media  euribor desconocido
#
#   nr.employed   y        date  latitude  longitude  \
# 0        5191  No  2019-08-02    41.495    -71.233
# 1        5191  No  2016-09-14    34.601    -83.923
# 2        5191  No  2019-02-15    34.939    -94.847
# 3        5191  No  2015-11-29    49.041    -70.308
# 4        5191  No  2017-01-29    38.033   -104.463
# 5        5191  No  2015-09-26    24.689   -101.643
# 6        5191  No  2019-01-25    31.456    -94.561
# 7        5191  No  2017-09-25    46.871   -122.235
# 8        5191  No  2018-01-18    44.632    -85.811
# 9        5191  No  2016-11-02    30.297   -117.382
#
#                                     id_  year  month  month_name  \
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079  2019      8      agosto
# 1  e9d37224-cb6f-4942-98d7-46672963d097  2016      9  septiembre
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b  2019      2     febrero
# 3  9991fafb-4447-451a-8be2-b0df6098d13e  2015     11   noviembre
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb  2017      1       enero
# 5  d63ede72-0b6d-45b1-8872-385ac6897f65  2015      9  septiembre
# 6  5e3483e5-236d-437d-8351-541f9d09b9dd  2019      1       enero
# 7  87fdc08b-30ae-4dab-803f-561ecdf27ff0  2017      9  septiembre
# 8  87b79988-2be5-419d-88f4-56655852c565  2018      1       enero
# 9  ea6b7d04-9271-4c0a-a01f-07795d164aba  2016     11   noviembre
#
#                  city           region country_code        country
# 0        Newport East     Rhode Island           US  United States
# 1           Dahlonega          Georgia           US  United States
# 2              Wister         Oklahoma           US  United States
# 3            Saguenay           Quebec           CA         Canada
# 4              Pueblo         Colorado           US  United States
# 5  Concepcion del Oro        Zacatecas           MX         Mexico
# 6             Redland            Texas           US  United States
# 7          Eatonville       Washington           US  United States
# 8       Greilickville         Michigan           US  United States
# 9          Las Brisas  Baja California           MX         Mexico
# Primeras filas de Customer:
#    Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
# 5  143854        0         1  2012-01-24                 26
# 6   76439        1         0  2012-08-15                  3
# 7  159686        1         1  2012-12-10                 21
# 8  179933        0         0  2012-08-22                 18
# 9   77504        1         0  2012-02-09                 18
#
#                                      ID  income_outlier_iqr  Children_total  \
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079               False               1
# 1  e9d37224-cb6f-4942-98d7-46672963d097               False               2
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b               False               2
# 3  9991fafb-4447-451a-8be2-b0df6098d13e               False               3
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb               False               3
# 5  d63ede72-0b6d-45b1-8872-385ac6897f65               False               1
# 6  5e3483e5-236d-437d-8351-541f9d09b9dd               False               1
# 7  87fdc08b-30ae-4dab-803f-561ecdf27ff0               False               2
# 8  87b79988-2be5-419d-88f4-56655852c565               False               0
# 9  ea6b7d04-9271-4c0a-a01f-07795d164aba               False               1
#
#    Customer_Tenure_Years
# 0                     13
# 1                     12
# 2                     13
# 3                     12
# 4                     13
# 5                     13
# 6                     13
# 7                     12
# 8                     13
# 9                     13

# %% [markdown]
# ## ESTADISTICAS BÁSICAS PARA VARIABLES NUMERICAS

# %%
print("Estadísticas numéricas - Bank")
print(df_bank.describe())

print("\nEstadísticas numéricas - Customer")
print(df_customer.describe())
# Out:
# Estadísticas numéricas - Bank
#                 age      duration      campaign      previous  cons.price.idx  \
# count  42752.000000  42752.000000  42752.000000  42752.000000    42752.000000
# mean      39.745018      4.296123      2.566383      0.174237       93.576226
# std        9.822489      4.312981      2.770606      0.497828        0.576815
# min       17.000000      0.000000      1.000000      0.000000       92.201000
# 25%       33.000000      1.700000      1.000000      0.000000       93.075000
# 50%       38.000000      2.980000      2.000000      0.000000       93.749000
# 75%       46.000000      5.320000      3.000000      0.000000       93.994000
# max       98.000000     81.970000     56.000000      7.000000       94.767000
#
#            latitude     longitude          year         month
# count  42752.000000  42752.000000  42752.000000  42752.000000
# mean      36.857781    -95.939502   2017.001310      6.502058
# std        7.225806     16.747650      1.414312      3.448718
# min       24.396000   -124.997000   2015.000000      1.000000
# 25%       30.616000   -110.490000   2016.000000      4.000000
# 50%       36.763000    -95.902000   2017.000000      7.000000
# 75%       43.113000    -81.437000   2018.000000     10.000000
# max       49.384000    -66.937000   2019.000000     12.000000
#
# Estadísticas numéricas - Customer
#               Income       Kidhome      Teenhome  NumWebVisitsMonth  \
# count   43170.000000  43170.000000  43170.000000       43170.000000
# mean    93227.389622      1.004749      0.998633          16.591290
# std     50498.181989      0.815996      0.816008           9.241769
# min      5841.000000      0.000000      0.000000           1.000000
# 25%     49608.000000      0.000000      0.000000           9.000000
# 50%     93009.500000      1.000000      1.000000          17.000000
# 75%    136740.500000      2.000000      2.000000          25.000000
# max    180802.000000      2.000000      2.000000          32.000000
#
#        Children_total  Customer_Tenure_Years
# count    43170.000000           43170.000000
# mean         2.003382              11.889298
# std          1.152982               0.980691
# min          0.000000              10.000000
# 25%          1.000000              11.000000
# 50%          2.000000              12.000000
# 75%          3.000000              13.000000
# max          4.000000              13.000000

# %% [markdown]
# ## ESTADISTICAS BASICAS PARA VARIABLES CATEGORICAS

# %%
print("Estadísticas categóricas - Bank")
print(df_bank.describe(include=['object', 'category']))

print("\nEstadísticas categóricas - Customer")
print(df_customer.describe(include=['object', 'category']))
# Out:
# Estadísticas categóricas - Bank
#                    job marital education default housing   loan contact  \
# count            42752   42752     42752   42752   42752  42752   42752
# unique              12       4         6       3       3      3       2
# top     administrativo  casado    basico      no      sí     no   móvil
# freq             10802   25840     12986   33810   22367  35244   27232
#
#               pdays     poutcome        emp.var.rate    cons.conf.idx  \
# count         42752        42752               42752            42752
# unique            2            3                   2                3
# top     no_contacto  inexistente  crecimiento empleo  confianza media
# freq          41190        36883               24857            18422
#
#            euribor3m nr.employed      y        date  \
# count          42752       42752  42752       42752
# unique             4          11      2        1825
# top     euribor bajo      5228,1     No  2018-02-28
# freq           11603       16878  37941          95
#
#                                          id_ month_name      city      region  \
# count                                  42752      42752     42752       42478
# unique                                 42752         12      6574          87
# top     089b39d8-e4d0-461b-87d4-814d71e0e079  noviembre  Hamilton  California
# freq                                       1       3603       931        2926
#
#        country_code        country
# count         42752          42752
# unique            7              7
# top              US  United States
# freq          32055          32055
#
# Estadísticas categóricas - Customer
#        Dt_Customer                                    ID
# count        43170                                 43170
# unique        1096                                 43170
# top     2012-08-10  089b39d8-e4d0-461b-87d4-814d71e0e079
# freq            79                                     1

# %% [markdown]
# # Análisis preliminar, limpieza y transformación completados.
#
# He completado el análisis preliminar de los datasets customer y bank.
#
# Se exploraron las variables, valores nulos y duplicados.
#
# Se aplicaron transformaciones: imputación, estandarización de categorías, creación de nuevas variables (total_hijos, antigüedad_cliente, categorización de confianza y euribor, etc.).
#
# Se eliminaron columnas irrelevantes (Unnamed).
#
# Se verificaron outliers y distribuciones.
#
# Los datos limpios se guardaron en Data/Output/ (customer_clean.csv y bank_clean.csv).
